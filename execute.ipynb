# %% [markdown]
# A one time execution

# %%
# %cd ..
# Out:
# /content

# %%
# !rm -rf ADV_ML
# !git clone https://auth_key@github.com/mustaphouni04/ADV_ML.git
# %cd ADV_ML
# Out:
# Cloning into 'ADV_ML'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 300 (delta 154), reused 233 (delta 88), pack-reused 0 (from 0)
# Receiving objects: 100% (300/300), 576.11 KiB | 10.11 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# /content/ADV_ML

# %%
# !ls
# !uv sync 
# !sed -i '1i import os\nos.environ["MPLBACKEND"]="Agg"' /content/ADV_ML/utils/dataset.py
# !wandb login wandb_api_key
# !uv run python train.py --batch-size 1
